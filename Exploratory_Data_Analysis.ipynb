# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://github.com/hagarwal011/Movie_Data_Analysis/raw/refs/heads/main/Movie_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                    title  vote_average release_date  runtime  \
# 0        2476              Role Models         6.492    11/7/2008       99
# 1       27540  The Outlaw and His Wife         7.216     1/1/1918      111
# 2       18966                Lowriders         6.686    4/28/2017       99
# 3       26417          Out of the Blue         6.382   10/12/2006      103
# 4       24712            Hold Me Tight         6.475     9/8/2021       95
#
#                  genres
# 0                Comedy
# 1                 Drama
# 2  Drama, Action, Crime
# 3          Drama, Crime
# 4                 Drama

# %%
df = df.drop(columns = ['Unnamed: 0'])

# %%
df.columns = ['Title', 'Rating', 'Release Date', 'Runtime', 'Genres']

# %%
df.head()
# Out:
#                      Title  Rating Release Date  Runtime                Genres
# 0              Role Models   6.492    11/7/2008       99                Comedy
# 1  The Outlaw and His Wife   7.216     1/1/1918      111                 Drama
# 2                Lowriders   6.686    4/28/2017       99  Drama, Action, Crime
# 3          Out of the Blue   6.382   10/12/2006      103          Drama, Crime
# 4            Hold Me Tight   6.475     9/8/2021       95                 Drama

# %%
df.isnull().sum()
# Out:
# Title            0
# Rating           0
# Release Date     0
# Runtime          0
# Genres          12
# dtype: int64

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14988 entries, 0 to 14999
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         14988 non-null  object
#  1   Rating        14988 non-null  float64
#  2   Release Date  14988 non-null  object
#  3   Runtime       14988 non-null  int64
#  4   Genres        14988 non-null  object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 702.6+ KB

# %%
df
# Out:
#                             Title  Rating Release Date  Runtime  \
# 0                     Role Models   6.492    11/7/2008       99
# 1         The Outlaw and His Wife   7.216     1/1/1918      111
# 2                       Lowriders   6.686    4/28/2017       99
# 3                 Out of the Blue   6.382   10/12/2006      103
# 4                   Hold Me Tight   6.475     9/8/2021       95
# ...                           ...     ...          ...      ...
# 14995                  Crossroads   5.197    2/15/2002       93
# 14996                  Nancy Drew   6.074    6/15/2007       99
# 14997      The Glenn Miller Story   6.941     1/4/1954      116
# 14998               I'm Not There   6.555    10/1/2007      135
# 14999  Mio in the Land of Faraway   6.084     7/1/1987       99
#
#                                            Genres
# 0                                          Comedy
# 1                                           Drama
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14988 entries, 0 to 14999
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         14988 non-null  object
#  1   Rating        14988 non-null  float64
#  2   Release Date  14988 non-null  object
#  3   Runtime       14988 non-null  int64
#  4   Genres        14988 non-null  object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 702.6+ KB

# %%
df.describe()
# Out:
#              Rating       Runtime
# count  14988.000000  14988.000000
# mean       6.411015     99.437350
# std        0.880185     28.329692
# min        1.840000      0.000000
# 25%        5.862000     90.000000
# 50%        6.464500     98.000000
# 75%        7.024250    111.000000
# max        9.769000    585.000000

# %%
df['Rating'] = df['Rating'].round(1)

# %%
df.head()
# Out:
#                      Title  Rating Release Date  Runtime                Genres
# 0              Role Models     6.5    11/7/2008       99                Comedy
# 1  The Outlaw and His Wife     7.2     1/1/1918      111                 Drama
# 2                Lowriders     6.7    4/28/2017       99  Drama, Action, Crime
# 3          Out of the Blue     6.4   10/12/2006      103          Drama, Crime
# 4            Hold Me Tight     6.5     9/8/2021       95                 Drama

# %%
df.to_csv('Movie_data_cleaned.csv')
