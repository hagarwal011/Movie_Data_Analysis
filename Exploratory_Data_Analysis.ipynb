# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://github.com/hagarwal011/Movie_Data_Analysis/raw/refs/heads/main/Movie_data.csv")

# %%
df
# Out:
#        Unnamed: 0                                              title  \
# 0            2220                                     Small Soldiers
# 1          137946                                    Rooted in Peace
# 2          176037                                  Una Mirada al Mar
# 3         1020593  Williams: Violin Concerto No. 2 & Selected Fil...
# 4            3281                               Secret in Their Eyes
# ...           ...                                                ...
# 19995      312647                                   Zbraně pro Prahu
# 19996      993868                                      The Blind Man
# 19997      148220                                        Vishnulokam
# 19998      859296                Stryper: Live at the Whisky A Go Go
# 19999       78014                                   Watch Your Stern
#
#        vote_average release_date  runtime  \
# 0             6.524   1998-07-10      110
# 1             5.800   2016-09-22       97
# 2             3.800   2011-07-08       95
# 3             0.000   2022-02-12       99
# 4             6.386   2015-10-14      111
# ...             ...          ...      ...
# 19995         4.000   1975-05-02       73
# 19996         0.000   1960-01-01       81
# 19997         6.300   1991-03-31      119
# 19998         0.000   2014-09-23      166
# 19999         5.700   1960-10-14       90
#
#                                                   genres
# 0      Comedy, Adventure, Fantasy, Science Fiction, A...
# 1                                            Documentary
# 2                                          Family, Drama
# 3                                                  Music
# 4                        Thriller, Mystery, Drama, Crime
# ...                                                  ...
# 19995                                         War, Drama
# 19996                                              Drama
# 19997                                              Drama
# 19998                                              Music
# 19999                                             Comedy
#
# [20000 rows x 6 columns]

# %%
df = df.drop(columns = ['Unnamed: 0'])

# %%
df.columns = ['Title', 'Rating', 'Release Date', 'Runtime', 'Genres']

# %%
df.head()
# Out:
#                                                Title  Rating Release Date  \
# 0                                     Small Soldiers   6.524   1998-07-10
# 1                                    Rooted in Peace   5.800   2016-09-22
# 2                                  Una Mirada al Mar   3.800   2011-07-08
# 3  Williams: Violin Concerto No. 2 & Selected Fil...   0.000   2022-02-12
# 4                               Secret in Their Eyes   6.386   2015-10-14
#
#    Runtime                                             Genres
# 0      110  Comedy, Adventure, Fantasy, Science Fiction, A...
# 1       97                                        Documentary
# 2       95                                      Family, Drama
# 3       99                                              Music
# 4      111                    Thriller, Mystery, Drama, Crime

# %%
df.isnull().sum()
# Out:
# Title           0
# Rating          0
# Release Date    0
# Runtime         0
# Genres          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         20000 non-null  object
#  1   Rating        20000 non-null  float64
#  2   Release Date  20000 non-null  object
#  3   Runtime       20000 non-null  int64
#  4   Genres        20000 non-null  object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 781.4+ KB

# %%
df['Release Year'] = pd.to_datetime(df['Release Date']).dt.year

# %%
df
# Out:
#                                                    Title  Rating Release Date  \
# 0                                         Small Soldiers   6.524   1998-07-10
# 1                                        Rooted in Peace   5.800   2016-09-22
# 2                                      Una Mirada al Mar   3.800   2011-07-08
# 3      Williams: Violin Concerto No. 2 & Selected Fil...   0.000   2022-02-12
# 4                                   Secret in Their Eyes   6.386   2015-10-14
# ...                                                  ...     ...          ...
# 19995                                   Zbraně pro Prahu   4.000   1975-05-02
# 19996                                      The Blind Man   0.000   1960-01-01
# 19997                                        Vishnulokam   6.300   1991-03-31
# 19998                Stryper: Live at the Whisky A Go Go   0.000   2014-09-23
# 19999                                   Watch Your Stern   5.700   1960-10-14
#
#        Runtime                                             Genres  \
# 0          110  Comedy, Adventure, Fantasy, Science Fiction, A...
# 1           97                                        Documentary
# 2           95                                      Family, Drama
# 3           99                                              Music
# 4          111                    Thriller, Mystery, Drama, Crime
# ...        ...                                                ...
# 19995       73                                         War, Drama
# 19996       81                                              Drama
# 19997      119                                              Drama
# 19998      166                                              Music
# 19999       90                                             Comedy
#
#        Release Year
# 0              1998
# 1              2016
# 2              2011
# 3              2022
# 4              2015
# ...             ...
# 19995          1975
# 19996          1960
# 19997          1991
# 19998          2014
# 19999          1960
#
# [20000 rows x 6 columns]

# %%
df['Release Year'].value_counts()
# Out:
# Release Year
# 2022    868
# 2021    779
# 2019    735
# 2017    728
# 2018    719
#        ...
# 2028      1
# 2026      1
# 1912      1
# 2029      1
# 1911      1
# Name: count, Length: 118, dtype: int64

# %%
df['Rating'] = df['Rating'].round(1)

# %%
df['Release Year'] = df['Release Year'].astype(int)

# %%
df = df[df['Release Year'] < 2025]

# %%
df['Release Month'] = pd.to_datetime(df['Release Date']).dt.month_name()
# Out:
# <ipython-input-43-065127b7c6eb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Release Month'] = pd.to_datetime(df['Release Date']).dt.month_name()

# %%
df
# Out:
#                                                    Title  Rating Release Date  \
# 0                                         Small Soldiers     6.5   1998-07-10
# 1                                        Rooted in Peace     5.8   2016-09-22
# 2                                      Una Mirada al Mar     3.8   2011-07-08
# 3      Williams: Violin Concerto No. 2 & Selected Fil...     0.0   2022-02-12
# 4                                   Secret in Their Eyes     6.4   2015-10-14
# ...                                                  ...     ...          ...
# 19995                                   Zbraně pro Prahu     4.0   1975-05-02
# 19996                                      The Blind Man     0.0   1960-01-01
# 19997                                        Vishnulokam     6.3   1991-03-31
# 19998                Stryper: Live at the Whisky A Go Go     0.0   2014-09-23
# 19999                                   Watch Your Stern     5.7   1960-10-14
#
#        Runtime                                             Genres  \
# 0          110  Comedy, Adventure, Fantasy, Science Fiction, A...
# 1           97                                        Documentary
# 2           95                                      Family, Drama
# 3           99                                              Music
# 4          111                    Thriller, Mystery, Drama, Crime
# ...        ...                                                ...
# 19995       73                                         War, Drama
# 19996       81                                              Drama
# 19997      119                                              Drama
# 19998      166                                              Music
# 19999       90                                             Comedy
#
#        Release Year Release Month
# 0              1998          July
# 1              2016     September
# 2              2011          July
# 3              2022      February
# 4              2015       October
# ...             ...           ...
# 19995          1975           May
# 19996          1960       January
# 19997          1991         March
# 19998          2014     September
# 19999          1960       October
#
# [19989 rows x 7 columns]

# %%
df['Release Weekday'] = pd.to_datetime(df['Release Date']).dt.day_name()
# Out:
# <ipython-input-45-3dd5018e98fc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Release Weekday'] = pd.to_datetime(df['Release Date']).dt.day_name()

# %%
df
# Out:
#                                                    Title  Rating Release Date  \
# 0                                         Small Soldiers     6.5   1998-07-10
# 1                                        Rooted in Peace     5.8   2016-09-22
# 2                                      Una Mirada al Mar     3.8   2011-07-08
# 3      Williams: Violin Concerto No. 2 & Selected Fil...     0.0   2022-02-12
# 4                                   Secret in Their Eyes     6.4   2015-10-14
# ...                                                  ...     ...          ...
# 19995                                   Zbraně pro Prahu     4.0   1975-05-02
# 19996                                      The Blind Man     0.0   1960-01-01
# 19997                                        Vishnulokam     6.3   1991-03-31
# 19998                Stryper: Live at the Whisky A Go Go     0.0   2014-09-23
# 19999                                   Watch Your Stern     5.7   1960-10-14
#
#        Runtime                                             Genres  \
# 0          110  Comedy, Adventure, Fantasy, Science Fiction, A...
# 1           97                                        Documentary
# 2           95                                      Family, Drama
# 3           99                                              Music
# 4          111                    Thriller, Mystery, Drama, Crime
# ...        ...                                                ...
# 19995       73                                         War, Drama
# 19996       81                                              Drama
# 19997      119                                              Drama
# 19998      166                                              Music
# 19999       90                                             Comedy
#
#        Release Year Release Month Release Weekday
# 0              1998          July          Friday
# 1              2016     September        Thursday
# 2              2011          July          Friday
# 3              2022      February        Saturday
# 4              2015       October       Wednesday
# ...             ...           ...             ...
# 19995          1975           May          Friday
# 19996          1960       January          Friday
# 19997          1991         March          Sunday
# 19998          2014     September         Tuesday
# 19999          1960       October          Friday
#
# [19989 rows x 8 columns]

# %%
df.describe()
# Out:
#              Rating       Runtime  Release Year
# count  19989.000000  19989.000000  19989.000000
# mean       3.858797     99.142378   1998.105508
# std        3.114654     73.243930     24.504171
# min        0.000000     60.000000   1911.000000
# 25%        0.000000     82.000000   1985.000000
# 50%        5.000000     92.000000   2007.000000
# 75%        6.400000    105.000000   2017.000000
# max       10.000000   9000.000000   2024.000000

# %%
df.to_csv('Movie_data_cleaned.csv')
